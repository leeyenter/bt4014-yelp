# %% [markdown]
# # Filtering Reviews By Business

# %%
import pandas as pd
import progressbar

# %%
business = pd.read_json('data/business.json', lines=True, orient='columns')
business.drop(['attributes', 'hours'], axis=1, inplace=True)

# %%
business.head()
# Out:
#                           address             business_id  \
# 0     2818 E Camino Acequia Drive  1SWheh84yJXfytovILXOAQ
# 1            30 Eglinton Avenue W  QXAEGFB4oINsVuTFxEYKFQ
# 2       10110 Johnston Rd, Ste 15  gnKjwL_1w79qoiV3IC_xQQ
# 3   15655 W Roosevelt St, Ste 237  xvX2CttrVhyG2z1dFg_0xw
# 4  4209 Stuart Andrew Blvd, Ste F  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  is_open  \
# 0                                  Golf, Active Life      Phoenix        0
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga        1
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte        1
# 3                      Insurance, Financial Services     Goodyear        1
# 4  Plumbing, Shopping, Local Services, Home Servi...    Charlotte        1
#
#     latitude   longitude                             name postal_code  \
# 0  33.522143 -112.018481       Arizona Biltmore Golf Club       85016
# 1  43.605499  -79.652289       Emerald Chinese Restaurant     L5R 3E7
# 2  35.092564  -80.859132      Musashi Japanese Restaurant       28210
# 3  33.455613 -112.395596  Farmers Insurance - Paul Lorenz       85338
# 4  35.190012  -80.887223              Queen City Plumbing       28217
#
#    review_count  stars state
# 0             5    3.0    AZ
# 1           128    2.5    ON
# 2           170    4.0    NC
# 3             3    5.0    AZ
# 4             4    4.0    NC

# %%
business_name = "The Cheesecake Factory"

# %%
businesses = business[business.name == business_name].drop(['categories', 'postal_code', 'is_open', 'name'], axis=1)
businesses.set_index('business_id', inplace=True)
businesses
# Out:
#                                                    address           city  \
# business_id
# eSlmVbicgkhtD9niSuReJw                      24265 Cedar Rd      Lyndhurst
# L8rJht4Jw_BuR8gsckEWYg             4400 Sharon Rd, Space A      Charlotte
# vXEZ-r6fah-5Fjt3a6c-Gw                       415 S 27th St     Pittsburgh
# htVvtLIFftBLqzRISjReDw                3401 Dufferin Street        Toronto
# I-5qHCVwT7k_KH67-YOx3A             160 S Green Valley Pkwy      Henderson
# NoA6bD6W7z_Aztk_cOU5cg  505 S Grand Central Pkwy, Ste 3201      Las Vegas
# 3oTVApC-eUzpGjrOVxIr5g         2402 E Camelback, Space 101        Phoenix
# 1NNBpiQ3rUT-7T8ch45SVA               148 Crocker Park Blvd       Westlake
# 7ADjU1ZmRfUeMebjbYU3kw              1000 Ross Park Mall Dr  Ross Township
# -Ylpy3VyRWwubf9dysuwjQ               3500 S Las Vegas Blvd      Las Vegas
# HwEDsb1xtRBTuFwATTRjpA      3111 W Chandler Blvd, Ste 2100       Chandler
# eZcCFV-8X91ZSnmB9807bw         750 S Rampart Blvd, Bldg 17      Las Vegas
# dPGs5b0N9MarZjVgQVelGQ                    16134 N 83rd Ave         Peoria
# adU58x75VWjbsyFdoO_m3w                      1 W Towne Mall        Madison
# S5o2kplwZtc9XWdktq_GcQ                 6613 E Southern Ave           Mesa
# 5diHqpk_JSC4p8tIo4APow               15230 N Scottsdale Rd     Scottsdale
#
#                          latitude   longitude  review_count  stars state
# business_id
# eSlmVbicgkhtD9niSuReJw  41.502300  -81.502145           223    3.5    OH
# L8rJht4Jw_BuR8gsckEWYg  35.151587  -80.830559           447    3.0    NC
# vXEZ-r6fah-5Fjt3a6c-Gw  40.428411  -79.965348           245    3.5    PA
# htVvtLIFftBLqzRISjReDw  43.724684  -79.454173           450    3.0    ON
# I-5qHCVwT7k_KH67-YOx3A  36.022082 -115.083185           654    3.5    NV
# NoA6bD6W7z_Aztk_cOU5cg  36.166142 -115.156400           308    3.5    NV
# 3oTVApC-eUzpGjrOVxIr5g  33.510305 -112.029567           414    3.5    AZ
# 1NNBpiQ3rUT-7T8ch45SVA  41.460132  -81.950880           160    3.0    OH
# 7ADjU1ZmRfUeMebjbYU3kw  40.544559  -80.008739           152    3.5    PA
# -Ylpy3VyRWwubf9dysuwjQ  36.117453 -115.176688           663    3.5    NV
# HwEDsb1xtRBTuFwATTRjpA  33.302145 -111.897866           439    3.0    AZ
# eZcCFV-8X91ZSnmB9807bw  36.164628 -115.289207           686    3.5    NV
# dPGs5b0N9MarZjVgQVelGQ  33.633252 -112.236120           376    3.0    AZ
# adU58x75VWjbsyFdoO_m3w  43.057191  -89.505467           172    3.0    WI
# S5o2kplwZtc9XWdktq_GcQ  33.391412 -111.689050           262    3.5    AZ
# 5diHqpk_JSC4p8tIo4APow  33.624993 -111.926283           351    3.5    AZ

# %% [markdown]
# Select all reviews that match any of these businesses

# %%
num_chunks = 50
chunk_size = 6685900 / num_chunks

# %%
reviews = pd.DataFrame()
bar = progressbar.ProgressBar(max_value=num_chunks)

df = pd.read_json('data/review.json', lines=True, orient='columns', chunksize=chunk_size)
i = 0
for chunk in df:
    chunk.set_index('business_id', inplace=True)
    joined = businesses.join(chunk, lsuffix='_biz', how='inner')
    reviews = reviews.append(joined)
    i += 1
    bar.update(i)

reviews.shape[0]
# Out:
# 100% (50 of 50) |########################| Elapsed Time: 0:01:32 ETA:  00:00:00
# 6226

# %%
pd.DataFrame(reviews.groupby(reviews.index).size().sort_values(ascending=False))
# Out:
#                           0
# business_id
# eZcCFV-8X91ZSnmB9807bw  721
# I-5qHCVwT7k_KH67-YOx3A  679
# -Ylpy3VyRWwubf9dysuwjQ  677
# L8rJht4Jw_BuR8gsckEWYg  465
# htVvtLIFftBLqzRISjReDw  463
# HwEDsb1xtRBTuFwATTRjpA  454
# 3oTVApC-eUzpGjrOVxIr5g  432
# dPGs5b0N9MarZjVgQVelGQ  390
# 5diHqpk_JSC4p8tIo4APow  365
# NoA6bD6W7z_Aztk_cOU5cg  317
# S5o2kplwZtc9XWdktq_GcQ  276
# vXEZ-r6fah-5Fjt3a6c-Gw  254
# eSlmVbicgkhtD9niSuReJw  232
# adU58x75VWjbsyFdoO_m3w  179
# 1NNBpiQ3rUT-7T8ch45SVA  165
# 7ADjU1ZmRfUeMebjbYU3kw  157

# %%
reviews = reviews.reset_index().set_index('review_id')

# %%
reviews.to_parquet('data/'+business_name+'_reviews.parquet')

# %%
reviews.head()
# Out:
#                                    business_id                  address  \
# review_id
# rsVqYKtEZykBZqwur6QyVw  L8rJht4Jw_BuR8gsckEWYg  4400 Sharon Rd, Space A
# T5dE90hplvP7UWQqYxYMTg  L8rJht4Jw_BuR8gsckEWYg  4400 Sharon Rd, Space A
# j5MrhwuMcvNkHO4q5ocdWg  L8rJht4Jw_BuR8gsckEWYg  4400 Sharon Rd, Space A
# yHTyWcbGR30Y9tXB8nPpSQ  L8rJht4Jw_BuR8gsckEWYg  4400 Sharon Rd, Space A
# F813bToytGklZok1WVxl6w  L8rJht4Jw_BuR8gsckEWYg  4400 Sharon Rd, Space A
#
#                              city   latitude  longitude  review_count  \
# review_id
# rsVqYKtEZykBZqwur6QyVw  Charlotte  35.151587 -80.830559           447
# T5dE90hplvP7UWQqYxYMTg  Charlotte  35.151587 -80.830559           447
# j5MrhwuMcvNkHO4q5ocdWg  Charlotte  35.151587 -80.830559           447
# yHTyWcbGR30Y9tXB8nPpSQ  Charlotte  35.151587 -80.830559           447
# F813bToytGklZok1WVxl6w  Charlotte  35.151587 -80.830559           447
#
#                         stars_biz state  cool                date  funny  \
# review_id
# rsVqYKtEZykBZqwur6QyVw        3.0    NC     0 2017-02-09 04:06:45      0
# T5dE90hplvP7UWQqYxYMTg        3.0    NC     0 2013-06-24 15:00:55      0
# j5MrhwuMcvNkHO4q5ocdWg        3.0    NC     0 2016-12-19 07:12:54      0
# yHTyWcbGR30Y9tXB8nPpSQ        3.0    NC     0 2014-04-19 14:11:00      0
# F813bToytGklZok1WVxl6w        3.0    NC     0 2016-05-31 01:54:07      0
#
#                         stars  \
# review_id
# rsVqYKtEZykBZqwur6QyVw      5
# T5dE90hplvP7UWQqYxYMTg      2
# j5MrhwuMcvNkHO4q5ocdWg      5
# yHTyWcbGR30Y9tXB8nPpSQ      1
# F813bToytGklZok1WVxl6w      2
#
#                                                                      text  \
# review_id
# rsVqYKtEZykBZqwur6QyVw  Famous for its cheesecake and infamous for its...
# T5dE90hplvP7UWQqYxYMTg  I want to preface this review by admitting I d...
# j5MrhwuMcvNkHO4q5ocdWg  Went here for me and my boyfriends anniversary...
# yHTyWcbGR30Y9tXB8nPpSQ  I'm not sure if I came in at a bad time... I c...
# F813bToytGklZok1WVxl6w  Ive eaten at Cheesecake Factory at other locat...
#
#                         useful                 user_id
# review_id
# rsVqYKtEZykBZqwur6QyVw       0  HFFiM63x9asevqVOZG5GBQ
# T5dE90hplvP7UWQqYxYMTg       0  K1osyO04_hXoDKyGqe_V2Q
# j5MrhwuMcvNkHO4q5ocdWg       0  GOk6jLtou4Gufxo-rtX5ZA
# yHTyWcbGR30Y9tXB8nPpSQ       0  BCHZd09vfR1ztLlFeTrzbQ
# F813bToytGklZok1WVxl6w       3  X3h37GG6Za3qhVZiOnzIcw

# %% [markdown]
# # Applying NLP to the reviews

# %%
import spacy
from tqdm import tqdm_notebook
tqdm_notebook().pandas()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
nlp = spacy.load("en_core_web_lg")

# %%
business_name = 'The Cheesecake Factory'
df = pd.read_parquet('data/' + business_name + '_reviews.parquet')

# %%
df['spacy'] = df.text.progress_apply(nlp)
# Out:
# HBox(children=(IntProgress(value=0, max=6226), HTML(value='')))

# %%
df.to_pickle("data/" + business_name + "_spacy", compression=None)
