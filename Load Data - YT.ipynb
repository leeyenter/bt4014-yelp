# %% [markdown]
# # Load Data

# %%
import pandas as pd
import json
import progressbar

# %% [markdown]
# ## Load Reviews
# First, load the reviews. We can use chunksize to limit the number of reviews selected.

# %%
num_reviews = 50000

# %%
df = pd.read_json('data/review.json', lines=True, orient='columns', chunksize=num_reviews)
for chunk in df:
    review = chunk
    break
review.set_index('review_id', inplace=True)
review.head()
# Out:
#                                    business_id  cool                date  \
# review_id
# Q1sbwvVQXV2734tPgoKj4Q  ujmEBvifdJM6h6RLv4wQIg     0 2013-05-07 04:34:36
# GJXCdrto3ASJOqKeVWPi6Q  NZnhc2sEQy3RmzKTZnqtwQ     0 2017-01-14 21:30:33
# 2TzJjDVDEuAW6MR5Vuc1ug  WTqjgwHlXbSFevF32_DJVw     0 2016-11-09 20:09:03
# yi0R0Ugj_xUx_Nek0-_Qig  ikCg8xy5JIg_NGPx-MSIDA     0 2018-01-09 20:56:38
# 11a8sVPMUFtaC7_ABRkmtw  b1b1eb3uo-w561D0ZfCEiQ     0 2018-01-30 23:07:38
#
#                         funny  stars  \
# review_id
# Q1sbwvVQXV2734tPgoKj4Q      1      1
# GJXCdrto3ASJOqKeVWPi6Q      0      5
# 2TzJjDVDEuAW6MR5Vuc1ug      0      5
# yi0R0Ugj_xUx_Nek0-_Qig      0      5
# 11a8sVPMUFtaC7_ABRkmtw      0      1
#
#                                                                      text  \
# review_id
# Q1sbwvVQXV2734tPgoKj4Q  Total bill for this horrible service? Over $8G...
# GJXCdrto3ASJOqKeVWPi6Q  I *adore* Travis at the Hard Rock's new Kelly ...
# 2TzJjDVDEuAW6MR5Vuc1ug  I have to say that this office really has it t...
# yi0R0Ugj_xUx_Nek0-_Qig  Went in for a lunch. Steak sandwich was delici...
# 11a8sVPMUFtaC7_ABRkmtw  Today was my second out of three sessions I ha...
#
#                         useful                 user_id
# review_id
# Q1sbwvVQXV2734tPgoKj4Q       6  hG7b0MtEbXx5QzbzE6C_VA
# GJXCdrto3ASJOqKeVWPi6Q       0  yXQM5uF2jS6es16SJzNHfg
# 2TzJjDVDEuAW6MR5Vuc1ug       3  n6-Gk65cPZL6Uz8qRm3NYw
# yi0R0Ugj_xUx_Nek0-_Qig       0  dacAIZ6fTM6mqwW5uxkskg
# 11a8sVPMUFtaC7_ABRkmtw       7  ssoyf2_x0EQMed6fgHeMyQ

# %% [markdown]
# ## Load Supplementary Data
# Next, load the corresponding tables. In order to save memory, we only load the data that is referenced in the reviews table.

# %%
business_ids = review.business_id.unique()
user_ids = review.user_id.unique()

# %%
def load_data(filename, filters, stop_when_done):
    bar = progressbar.ProgressBar(widgets=[progressbar.AnimatedMarker(), " ", progressbar.Counter(), " ", progressbar.BouncingBar(), " ", progressbar.Timer()])
    i = 0
    df_dict = {}
    with open("data/"+filename+".json", encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            add = True
            for col_to_filter, filter_items in filters:
                if (obj[col_to_filter] not in filter_items):
                    add = False
                    break
            if add:
                df_dict[i] = obj
                i+=1
                if stop_when_done and len(df_dict) == len(filter_items):
                    break
            bar.update(len(df_dict))
    bar.finish()
    return pd.DataFrame.from_dict(df_dict, 'index')

# %%
business = load_data('business', [('business_id', business_ids)], True)
business.set_index('business_id', inplace=True)
business.head()
# Out:
# | 10658 |                  #                            | Elapsed Time: 0:00:07
#                                                name  \
# business_id
# 1SWheh84yJXfytovILXOAQ   Arizona Biltmore Golf Club
# QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant
# gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant
# HhyxOkGAM07SRYtlQ4wMFQ          Queen City Plumbing
# 5t3KVdMnFgAYmSl1wYLhmA  The Kilted Buffalo Langtree
#
#                                                address         city state  \
# business_id
# 1SWheh84yJXfytovILXOAQ     2818 E Camino Acequia Drive      Phoenix    AZ
# QXAEGFB4oINsVuTFxEYKFQ            30 Eglinton Avenue W  Mississauga    ON
# gnKjwL_1w79qoiV3IC_xQQ       10110 Johnston Rd, Ste 15    Charlotte    NC
# HhyxOkGAM07SRYtlQ4wMFQ  4209 Stuart Andrew Blvd, Ste F    Charlotte    NC
# 5t3KVdMnFgAYmSl1wYLhmA        119 Landings Dr, Ste 101  Mooresville    NC
#
#                        postal_code   latitude   longitude  stars  \
# business_id
# 1SWheh84yJXfytovILXOAQ       85016  33.522143 -112.018481    3.0
# QXAEGFB4oINsVuTFxEYKFQ     L5R 3E7  43.605499  -79.652289    2.5
# gnKjwL_1w79qoiV3IC_xQQ       28210  35.092564  -80.859132    4.0
# HhyxOkGAM07SRYtlQ4wMFQ       28217  35.190012  -80.887223    4.0
# 5t3KVdMnFgAYmSl1wYLhmA       28117  35.527410  -80.868003    3.5
#
#                         review_count  is_open  \
# business_id
# 1SWheh84yJXfytovILXOAQ             5        0
# QXAEGFB4oINsVuTFxEYKFQ           128        1
# gnKjwL_1w79qoiV3IC_xQQ           170        1
# HhyxOkGAM07SRYtlQ4wMFQ             4        1
# 5t3KVdMnFgAYmSl1wYLhmA             9        1
#
#                                                                attributes  \
# business_id
# 1SWheh84yJXfytovILXOAQ                           {'GoodForKids': 'False'}
# QXAEGFB4oINsVuTFxEYKFQ  {'RestaurantsReservations': 'True', 'GoodForMe...
# gnKjwL_1w79qoiV3IC_xQQ  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
# HhyxOkGAM07SRYtlQ4wMFQ  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...
# 5t3KVdMnFgAYmSl1wYLhmA  {'BusinessParking': '{'garage': False, 'street...
#
#                                                                categories  \
# business_id
# 1SWheh84yJXfytovILXOAQ                                  Golf, Active Life
# QXAEGFB4oINsVuTFxEYKFQ  Specialty Food, Restaurants, Dim Sum, Imported...
# gnKjwL_1w79qoiV3IC_xQQ                  Sushi Bars, Restaurants, Japanese
# HhyxOkGAM07SRYtlQ4wMFQ  Plumbing, Shopping, Local Services, Home Servi...
# 5t3KVdMnFgAYmSl1wYLhmA  Bars, Nightlife, Pubs, Barbers, Beauty & Spas,...
#
#                                                                     hours
# business_id
# 1SWheh84yJXfytovILXOAQ                                               None
# QXAEGFB4oINsVuTFxEYKFQ  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# gnKjwL_1w79qoiV3IC_xQQ  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...
# HhyxOkGAM07SRYtlQ4wMFQ  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...
# 5t3KVdMnFgAYmSl1wYLhmA  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...

# %%
user = load_data('user', [('user_id', user_ids)], True)
user.set_index('user_id', inplace=True)
user.head()
# Out:
# | 42987 |                #                              | Elapsed Time: 0:05:40
#                           name  review_count        yelping_since  useful  \
# user_id
# dD0gZpBctWGdWo9WlGuhlA  Angela            17  2014-05-22 15:57:30      30
# MM4RJAeH6yuaN8oZDSt0RA   Nancy           361  2013-10-23 07:02:50    1114
# T0gWkTHWRChVUe_Dn1F8nw   Tanya           859  2005-07-20 22:38:17    1630
# NQffx45eJaeqhFcMadKUQA   Trace           124  2008-12-10 22:59:45     202
# gvXtMj3XuPr0xHjgmlmtng   Peter            47  2014-01-05 20:45:54      57
#
#                         funny  cool                               elite  \
# user_id
# dD0gZpBctWGdWo9WlGuhlA      4    14
# MM4RJAeH6yuaN8oZDSt0RA    279   665                 2015,2016,2017,2018
# T0gWkTHWRChVUe_Dn1F8nw    693  1244  2006,2007,2008,2009,2010,2011,2012
# NQffx45eJaeqhFcMadKUQA     70   185
# gvXtMj3XuPr0xHjgmlmtng     26    34                           2017,2018
#
#                                                                   friends  \
# user_id
# dD0gZpBctWGdWo9WlGuhlA  RZ6wS38wnlXyj-OOdTzBxA, l5jxZh1KsgI8rMunm-GN6A...
# MM4RJAeH6yuaN8oZDSt0RA  mbwrZ-RS76V1HoJ0bF_Geg, g64lOV39xSLRZO0aQQ6DeQ...
# T0gWkTHWRChVUe_Dn1F8nw  ctr_BlCf3Ogny-vLs8E9tQ, c6HT44PKCaXqzN_BdgKPCw...
# NQffx45eJaeqhFcMadKUQA  N-xeG3U6rUkjVtQ0o-5YZA, wnO99pBbGqwqOoTQM25iCw...
# gvXtMj3XuPr0xHjgmlmtng  CfGCj80EdA-xS-mTWlAn4Q, JgD2Rk9K07MkZgG7Nb9YzA...
#
#                         fans  average_stars  ...  compliment_more  \
# user_id                                      ...
# dD0gZpBctWGdWo9WlGuhlA     5           4.85  ...                0
# MM4RJAeH6yuaN8oZDSt0RA    39           4.08  ...                1
# T0gWkTHWRChVUe_Dn1F8nw    57           4.21  ...               16
# NQffx45eJaeqhFcMadKUQA    15           4.53  ...                3
# gvXtMj3XuPr0xHjgmlmtng     9           3.60  ...                0
#
#                         compliment_profile  compliment_cute  compliment_list  \
# user_id
# dD0gZpBctWGdWo9WlGuhlA                   0                0                0
# MM4RJAeH6yuaN8oZDSt0RA                   0                0                1
# T0gWkTHWRChVUe_Dn1F8nw                   7                7                3
# NQffx45eJaeqhFcMadKUQA                   0                2                0
# gvXtMj3XuPr0xHjgmlmtng                   0                0                0
#
#                         compliment_note  compliment_plain  compliment_cool  \
# user_id
# dD0gZpBctWGdWo9WlGuhlA                0                 2                0
# MM4RJAeH6yuaN8oZDSt0RA               16                57               80
# T0gWkTHWRChVUe_Dn1F8nw               31                72               95
# NQffx45eJaeqhFcMadKUQA               12                 8               14
# gvXtMj3XuPr0xHjgmlmtng                4                11                5
#
#                         compliment_funny  compliment_writer  compliment_photos
# user_id
# dD0gZpBctWGdWo9WlGuhlA                 0                  1                  0
# MM4RJAeH6yuaN8oZDSt0RA                80                 25                  5
# T0gWkTHWRChVUe_Dn1F8nw                95                 34                  2
# NQffx45eJaeqhFcMadKUQA                14                  3                  5
# gvXtMj3XuPr0xHjgmlmtng                 5                  4                  3
#
# [5 rows x 21 columns]

# %%
checkin = load_data('checkin', [('business_id', business_ids)], False)
checkin.set_index('business_id', inplace=True)
checkin.head()
# Out:
# | 9711 |                                 #              | Elapsed Time: 0:00:54
#                                                                      date
# business_id
# --I7YYLada0tSLkORTHb5Q  2014-11-07 00:51:45, 2014-11-10 23:51:38, 2014...
# --U98MNlDym2cLn36BBPgQ  2011-10-05 22:50:41, 2012-04-11 00:06:36, 2012...
# --wIGbLEhlpl_UeAIyDmZQ                                2015-06-06 20:01:06
# -000aQFeK6tqVLndf7xORg                                2018-10-17 21:16:27
# -092wE7j5HZOogMLAh40zA  2010-07-28 21:07:28, 2010-07-31 21:16:54, 2010...

# %%
photo = load_data('photo', [('business_id', business_ids)], False)
photo.set_index('business_id', inplace=True)
photo.head()
# Out:
# | 16319 |                                             # | Elapsed Time: 0:01:00
#                                           caption                photo_id  \
# business_id
# 50Anorn0DJXFhBr9a9_gHQ                             5IiIo5UKEW0lWqZ6sWrY_A
# 296PZdxSrtH08EUwCsOKMw                             1eDvPC4F8cGvuI2lGpIoEw
# 7eQoxWr9RzyCB9IFvqHUPA                             GuvDS21yJ5efL1Zo1EzGPA
# GCRvrxMSC1nzShyM4Y-guQ                Bar Dancers  hkV_CrgjTeJBTAWJWAO46w
# jGH9DMTUojegjQZ4anb1kQ  Eddie V's Edgewater Grill  D__lKlNV-3Ha_eps3Y9_CA
#
#                           label
# business_id
# 50Anorn0DJXFhBr9a9_gHQ   inside
# 296PZdxSrtH08EUwCsOKMw   inside
# 7eQoxWr9RzyCB9IFvqHUPA  outside
# GCRvrxMSC1nzShyM4Y-guQ   inside
# jGH9DMTUojegjQZ4anb1kQ   inside

# %%
# tip = load_data('tip', [('business_id', business_ids), ('user_id', user_ids)], False)
# tip.head()

# %%
import gc
gc.collect()
# Out:
# 42

# %% [markdown]
# ## Export Data
#
# We export the data for easier loading for future sessions.

# %%
review.to_pickle("data/"+str(num_reviews)+"_review.pkl")
business.to_pickle("data/"+str(num_reviews)+"_business.pkl")
user.to_pickle("data/"+str(num_reviews)+"_user.pkl")
checkin.to_pickle("data/"+str(num_reviews)+"_checkin.pkl")
photo.to_pickle("data/"+str(num_reviews)+"_photo.pkl")
